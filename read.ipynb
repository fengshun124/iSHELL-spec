# %%
import json
import os
import re

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from astropy.io import fits
from tqdm.auto import tqdm

# %% [markdown]
# # Collecting Information from FITS Files

# %%
# visualisation for the extracted spectral data
def plot_spec_orders(spec_df_dict, plot_label, exp_filename):
    fig, axes = plt.subplots(
        40, 1, figsize=(8, 80), dpi=300, gridspec_kw={'hspace': .14}
    )

    for (spec_order, axis) in zip(
            sorted(spec_df_by_order_dict.keys(), reverse=True), axes):
        df = spec_df_dict[spec_order]

        axis.errorbar(
            df['wvl_angstrom'], y=df['flux'],
            yerr=df['flux_err'], fmt='o',
            c='tab:blue', ecolor='darkgrey', mfc='None',
            ms=1, elinewidth=.6, mew=.6
        )
        axis.text(
            s=f'Order {spec_order}', x=.03, y=.9,
            va='top', ha='left', transform=axis.transAxes,
            font='monospace', fontsize=8
        )
        axis.text(
            s=f'avg. flux/$\sigma_\mathrm{{flux}}$={np.nanmean(df["flux"] / df["flux_err"]):.1f}',
            x=.97, y=.9, va='top', ha='right', transform=axis.transAxes,
            font='monospace', fontsize=8
        )
        axis.axhline(0, c='k', lw=.4, ls=':', alpha=.8)
        axis.set_ylabel('Flux', font='monospace', fontsize=10)

        plot_upper_threshold = np.ceil(np.nanpercentile(df['flux'], 99) / 6) * 6
        y_major_locator_base = max(6, (plot_upper_threshold // 4) // 6 * 6)
        y_minor_locator_base = y_major_locator_base / 3
        y_upper_lim = np.ceil(plot_upper_threshold / y_minor_locator_base) * y_minor_locator_base
        axis.set_ylim(-y_minor_locator_base, y_upper_lim)
        axis.yaxis.set_major_locator(
            plt.MultipleLocator(base=y_major_locator_base, offset=y_minor_locator_base))
        axis.yaxis.set_minor_locator(
            plt.MultipleLocator(base=y_minor_locator_base))

        axis.set_xlim(np.floor(df['wvl_angstrom'].min() / 5) * 5 - 5,
                      np.ceil(df['wvl_angstrom'].max() / 5) * 5 + 5)
        axis.xaxis.set_major_locator(plt.MultipleLocator(base=25))
        axis.xaxis.set_minor_locator(plt.MultipleLocator(base=5))

        axis.tick_params(axis='both', right=True, top=True,
                         labelsize=8, direction='in', length=5, which='major')
        axis.tick_params(axis='both', right=True, top=True,
                         labelsize=8, direction='in', length=4, which='minor')

    axes[-1].set_xlabel(r'$\lambda$ [$\AA$]', font='monospace', fontsize=10)

    # set the title of the plot
    axes[0].set_title(f'{plot_label}', font='monospace', fontsize=12)
    fig.savefig(exp_filename, bbox_inches='tight')
    plt.close(fig)

# %%
obs_date = 230615
combined_img_fits_file_dir = f'data/raw-combined/{obs_date}/'
spec_fits_file_dir = f'data/extracted/{obs_date}/'

# path to plots and summary files
exp_path = f'results/'
fig_exp_path = os.path.join(exp_path, f'figures/{obs_date}')
file_exp_path = os.path.join(exp_path, f'spec_files/{obs_date}')

# create directories if not exist
for path in [exp_path, fig_exp_path, file_exp_path]:
    if not os.path.isdir(path):
        os.makedirs(path)

# full orders ranging from 299 to 338
full_orders = range(299, 339)

# %% [markdown]
# ## Collection information from combined fits images

# %%
combined_img_info_dict = {}
combined_img_fits_filenames = [name for name in os.listdir(combined_img_fits_file_dir)
                               if re.search(r'combined(\d+-\d+)', name)]
for fits_img_filename in tqdm(sorted(
        combined_img_fits_filenames, key=lambda x: int(re.search(r'(\d+)-', x).group(1)))):
    print(f'processing \"{os.path.join(combined_img_fits_file_dir, fits_img_filename)}\"...')

    # import FITS data and header info
    with fits.open(os.path.join(combined_img_fits_file_dir, fits_img_filename)) as fits_img_file:
        fits_img_header = fits_img_file[0].header

    combined_img_info_dict[fits_img_filename] = {
        'src_img_fits_combined_img': json.dumps(
            re.findall(r'icm.*?\.a\.fits', str(fits_img_header['HISTORY']))),
    }

combined_img_info_df = pd.DataFrame(combined_img_info_dict).T
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# processing "data/raw-combined/230615/combined1-6.fits"...
# processing "data/raw-combined/230615/combined14-18.fits"...
# processing "data/raw-combined/230615/combined19-22.fits"...
# processing "data/raw-combined/230615/combined23-28.fits"...
# processing "data/raw-combined/230615/combined29-32.fits"...
# processing "data/raw-combined/230615/combined33-37.fits"...
# processing "data/raw-combined/230615/combined45-47.fits"...
# processing "data/raw-combined/230615/combined48-50.fits"...
# processing "data/raw-combined/230615/combined51-55.fits"...
# processing "data/raw-combined/230615/combined56-58.fits"...
# processing "data/raw-combined/230615/combined66-70.fits"...
# processing "data/raw-combined/230615/combined71-74.fits"...
# processing "data/raw-combined/230615/combined75-77.fits"...
# processing "data/raw-combined/230615/combined85-87.fits"...
# processing "data/raw-combined/230615/combined93-96.fits"...
# processing "data/raw-combined/230615/combined104-106.fits"...
# processing "data/raw-combined/230615/combined107-110.fits"...
# processing "data/raw-combined/230615/combined111-114.fits"...
# processing "data/raw-combined/230615/combined115-118.fits"...
# processing "data/raw-combined/230615/combined119-123.fits"...

# %% [markdown]
# ## Collecting Information from FITS Files

# %%
spec_info_dict = {}
spec_fits_filenames = [name for name in os.listdir(spec_fits_file_dir)
                       if name.startswith('combined_spectra')]
for spec_fits_filename in tqdm(sorted(
        spec_fits_filenames, key=lambda x: int(re.search(r'(\d+)-', x).group(1)))):
    spec_label = re.sub(
        r'combined_spectra(\d+-\d+)', r'spec\1', spec_fits_filename.split('.')[0])
    print(f'processing \"{os.path.join(spec_fits_file_dir, spec_fits_filename)}\"...')

    # import FITS data and header info
    with fits.open(os.path.join(spec_fits_file_dir, spec_fits_filename)) as fits_file:
        fits_spec_data = fits_file[0].data
        fits_spec_header = fits_file[0].header

    orders = [int(s) for s in fits_spec_header['ORDERS'].split(',')]

    # extract spectral data from each order
    spec_df_by_order_dict = {}
    snr_by_order_dict = {}
    for idx, order in enumerate(orders):
        spec_df_by_order_dict[order] = pd.DataFrame({
            'wvl_um': fits_spec_data[idx, 0, :],
            'wvl_angstrom': fits_spec_data[idx, 0, :] * 1e4,
            'flux': fits_spec_data[idx, 1, :],
            'flux_err': fits_spec_data[idx, 2, :]
        })

        order_snr = (lambda x: x[~np.isnan(x)])(
            spec_df_by_order_dict[order]['flux'] / spec_df_by_order_dict[order]['flux_err']
        )
        snr_by_order_dict[order] = {
            'mean': np.mean(order_snr) if len(order_snr) > 0 else np.nan,
            'std': np.std(order_snr) if len(order_snr) > 0 else np.nan
        }

    # plot the spectral data
    plot_spec_orders(
        spec_df_by_order_dict,
        f'{obs_date}-{spec_label} ({fits_spec_header["OBJECT"]})',
        os.path.join(fig_exp_path, f'{obs_date}-{spec_label}.png')
    )

    # collect information from FITS header
    spec_info_dict[spec_fits_filename] = {
        'object': fits_spec_header['OBJECT'],
        'extracted_spec_fits': spec_fits_filename,
        'combined_img_fits': fits_spec_header['AIMAGE'],
        'src_img_fits_spec': json.dumps(
            re.findall(r'icm.*?\.a\.fits', str(fits_spec_header['HISTORY']))),
        'flat_fits': fits_spec_header['FLAT'],
        'wvl_cal_fits': fits_spec_header['WAVECAL'],
        'obs_date': obs_date,
        'obs_humidity': fits_spec_header['TCS_HUM'],
        'obs_air_temp_deg': fits_spec_header['TCS_AIRT'],
        'obs_mean_wind_speed_mph': fits_spec_header['TCS_WMSP'],
        'obs_wind_direction_deg': fits_spec_header['TCS_WDIR'],
        'obs_elevation_deg': fits_spec_header['TCS_EL'],
        'obs_azimuth_deg': fits_spec_header['TCS_AZ'],
        'obs_ra_hms_fk5': fits_spec_header['RA'],
        'obs_dec_hms_fk5': fits_spec_header['DEC'],
        'obs_avg_mjd': fits_spec_header['AVE_MJD'],
        'obs_total_exp_time': fits_spec_header['TOTITIME'],
        'obs_exp_time': fits_spec_header['ITIME'],
        'obs_avg_air_mass': fits_spec_header['AVE_AM'],
        'num_img_combined': fits_spec_header['NIMCOMB'],
        **{f'ap_pos_order{order}': fits_spec_header.get(f'APOSO{order}', None)
           for order in full_orders},
        **{f'extn_range_order{order}': json.dumps(
            list(map(int, fits_spec_header.get(f'XROR{order}', '0,0').split(','))))
            for order in full_orders},
        **{f'snr_mean_order{order}': snr_by_order_dict[order]['mean']
        if order in snr_by_order_dict else np.nan
           for order in full_orders},
        **{f'snr_std_order{order}': snr_by_order_dict[order]['std']
        if order in snr_by_order_dict else np.nan
           for order in full_orders}
    }

    # save the DataFrames as hdf5 files
    with pd.HDFStore(os.path.join(file_exp_path, f'{obs_date}-{spec_label}.h5'), 'w') as store:
        for order, spec_df in spec_df_by_order_dict.items():
            store[f'order{order}'] = spec_df

spec_info_df = pd.DataFrame(spec_info_dict).T
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# processing "data/extracted/230615/combined_spectra1-6.fits"...
# processing "data/extracted/230615/combined_spectra14-18.fits"...
# processing "data/extracted/230615/combined_spectra19-22.fits"...
# processing "data/extracted/230615/combined_spectra23-28.fits"...
# processing "data/extracted/230615/combined_spectra29-32.fits"...
# processing "data/extracted/230615/combined_spectra33-37.fits"...
# processing "data/extracted/230615/combined_spectra45-47.fits"...
# processing "data/extracted/230615/combined_spectra48-50.fits"...
# processing "data/extracted/230615/combined_spectra51-55.fits"...
# processing "data/extracted/230615/combined_spectra56-58.fits"...
# processing "data/extracted/230615/combined_spectra66-70.fits"...
# processing "data/extracted/230615/combined_spectra71-74.fits"...
# processing "data/extracted/230615/combined_spectra75-77.fits"...
# processing "data/extracted/230615/combined_spectra85-87.fits"...
# processing "data/extracted/230615/combined_spectra93-96.fits"...
# processing "data/extracted/230615/combined_spectra104-106.fits"...
# processing "data/extracted/230615/combined_spectra107-110.fits"...
# processing "data/extracted/230615/combined_spectra111-114.fits"...
# processing "data/extracted/230615/combined_spectra115-118.fits"...
# processing "data/extracted/230615/combined_spectra119-123.fits"...

# %% [markdown]
# ## Merging the Summary DataFrames

# %%
merged_summary_df = pd.merge(
    spec_info_df, combined_img_info_df, left_on='combined_img_fits', right_index=True, how='left')

# check if 'src_img_fits_spec' and 'src_img_fits_combined_img' are consistent, if available
merged_summary_df['is_src_img_fits_log_consistent'] = merged_summary_df.apply(
    lambda x: x['src_img_fits_spec'] == x['src_img_fits_combined_img'], axis=1)
merged_summary_df['src_img_fits'] = merged_summary_df.apply(
    lambda x: x['src_img_fits_spec'] if x['is_src_img_fits_log_consistent']
    else x['src_img_fits_combined_img'],
    axis=1)

merged_summary_df['group'] = merged_summary_df['object'].apply(
    lambda x: 'Telluric_STD' if 'Telluric' in x
    else 'RV_STD' if 'RVSTD' in x
    else f'LP_2442_gp{x[0]}'
)

merged_summary_df[[
    'src_img_fits', 'is_src_img_fits_log_consistent',
    'src_img_fits_spec', 'src_img_fits_combined_img'
]]
# Out:
#                                                                    src_img_fits  \
# combined_spectra1-6.fits      ["icm.2023A023.230615.fname.00001.a.fits", "ic...
# combined_spectra14-18.fits    ["icm.2023A023.230615.fname.00014.a.fits", "ic...
# combined_spectra19-22.fits                                                  NaN
# combined_spectra23-28.fits                                                  NaN
# combined_spectra29-32.fits                                                  NaN
# combined_spectra33-37.fits                                                  NaN
# combined_spectra45-47.fits                                                  NaN
# combined_spectra48-50.fits                                                  NaN
# combined_spectra51-55.fits                                                  NaN
# combined_spectra56-58.fits    ["icm.2023A023.230615.fname.00056.a.fits", "ic...
# combined_spectra66-70.fits    ["icm.2023A023.230615.fname.00066.a.fits", "ic...
# combined_spectra71-74.fits    ["icm.2023A023.230615.fname.00071.a.fits", "ic...
# combined_spectra75-77.fits    ["icm.2023A023.230615.fname.00075.a.fits", "ic...
# combined_spectra85-87.fits    ["icm.2023A023.230615.fname.00085.a.fits", "ic...
# combined_spectra93-96.fits    ["icm.2023A023.230615.fname.00093.a.fits", "ic...
# combined_spectra104-106.fits  ["icm.2023A023.230615.fname.00104.a.fits", "ic...
# combined_spectra107-110.fits  ["icm.2023A023.230615.fname.00107.a.fits", "ic...
# combined_spectra111-114.fits  ["icm.2023A023.230615.fname.00111.a.fits", "ic...
# combined_spectra115-118.fits  ["icm.2023A023.230615.fname.00115.a.fits", "ic...
# combined_spectra119-123.fits  ["icm.2023A023.230615.fname.00119.a.fits", "ic...
#
#                               is_src_img_fits_log_consistent  \
# combined_spectra1-6.fits                                True
# combined_spectra14-18.fits                             False
# combined_spectra19-22.fits                             False
# combined_spectra23-28.fits                             False
# combined_spectra29-32.fits                             False
# combined_spectra33-37.fits                             False
# combined_spectra45-47.fits                             False
# combined_spectra48-50.fits                             False
# combined_spectra51-55.fits                             False
# combined_spectra56-58.fits                             False
# combined_spectra66-70.fits                             False
# combined_spectra71-74.fits                              True
# combined_spectra75-77.fits                             False
# combined_spectra85-87.fits                             False
# combined_spectra93-96.fits                              True
# combined_spectra104-106.fits                           False
# combined_spectra107-110.fits                            True
# combined_spectra111-114.fits                            True
# combined_spectra115-118.fits                            True
# combined_spectra119-123.fits                           False
#
#                                                               src_img_fits_spec  \
# combined_spectra1-6.fits      ["icm.2023A023.230615.fname.00001.a.fits", "ic...
# combined_spectra14-18.fits                                                   []
# combined_spectra19-22.fits    ["icm.2023A023.230615.fname.00019.a.fits", "ic...
# combined_spectra23-28.fits    ["icm.2023A023.230615.fname.00023.a.fits", "ic...
# combined_spectra29-32.fits    ["icm.2023A023.230615.fname.00029.a.fits", "ic...
# combined_spectra33-37.fits                                                   []
# combined_spectra45-47.fits                                                   []
# combined_spectra48-50.fits                                                   []
# combined_spectra51-55.fits                                                   []
# combined_spectra56-58.fits                                                   []
# combined_spectra66-70.fits                                                   []
# combined_spectra71-74.fits    ["icm.2023A023.230615.fname.00071.a.fits", "ic...
# combined_spectra75-77.fits                                                   []
# combined_spectra85-87.fits                                                   []
# combined_spectra93-96.fits    ["icm.2023A023.230615.fname.00093.a.fits", "ic...
# combined_spectra104-106.fits                                                 []
# combined_spectra107-110.fits  ["icm.2023A023.230615.fname.00107.a.fits", "ic...
# combined_spectra111-114.fits  ["icm.2023A023.230615.fname.00111.a.fits", "ic...
# combined_spectra115-118.fits  ["icm.2023A023.230615.fname.00115.a.fits", "ic...
# combined_spectra119-123.fits                                                 []
#
#                                                       src_img_fits_combined_img
# combined_spectra1-6.fits      ["icm.2023A023.230615.fname.00001.a.fits", "ic...
# combined_spectra14-18.fits    ["icm.2023A023.230615.fname.00014.a.fits", "ic...
# combined_spectra19-22.fits                                                  NaN
# combined_spectra23-28.fits                                                  NaN
# combined_spectra29-32.fits                                                  NaN
# combined_spectra33-37.fits                                                  NaN
# combined_spectra45-47.fits                                                  NaN
# combined_spectra48-50.fits                                                  NaN
# combined_spectra51-55.fits                                                  NaN
# combined_spectra56-58.fits    ["icm.2023A023.230615.fname.00056.a.fits", "ic...
# combined_spectra66-70.fits    ["icm.2023A023.230615.fname.00066.a.fits", "ic...
# combined_spectra71-74.fits    ["icm.2023A023.230615.fname.00071.a.fits", "ic...
# combined_spectra75-77.fits    ["icm.2023A023.230615.fname.00075.a.fits", "ic...
# combined_spectra85-87.fits    ["icm.2023A023.230615.fname.00085.a.fits", "ic...
# combined_spectra93-96.fits    ["icm.2023A023.230615.fname.00093.a.fits", "ic...
# combined_spectra104-106.fits  ["icm.2023A023.230615.fname.00104.a.fits", "ic...
# combined_spectra107-110.fits  ["icm.2023A023.230615.fname.00107.a.fits", "ic...
# combined_spectra111-114.fits  ["icm.2023A023.230615.fname.00111.a.fits", "ic...
# combined_spectra115-118.fits  ["icm.2023A023.230615.fname.00115.a.fits", "ic...
# combined_spectra119-123.fits  ["icm.2023A023.230615.fname.00119.a.fits", "ic...

# %%
# adjust columns order
merged_summary_df = merged_summary_df[[
    'group', 'object', 'extracted_spec_fits', 'combined_img_fits', 'flat_fits', 'wvl_cal_fits',
    'src_img_fits', 'is_src_img_fits_log_consistent', 'src_img_fits_spec', 'src_img_fits_combined_img',
    *[col for col in merged_summary_df.columns if 'obs_' in col], 'num_img_combined',
    *[col for col in merged_summary_df.columns if 'ap_pos_order' in col],
    *[col for col in merged_summary_df.columns if 'extn_range_order' in col],
    *[val for pair in zip(
        sorted([col for col in merged_summary_df.columns if 'snr_mean_order' in col]),
        sorted([col for col in merged_summary_df.columns if 'snr_std_order' in col]))
      for val in pair]
]]
merged_summary_df
# Out:
#                                      group       object  \
# combined_spectra1-6.fits      Telluric_STD  TelluricSTD
# combined_spectra14-18.fits     LP_2442_gp5  559c3847e65
# combined_spectra19-22.fits     LP_2442_gp5  501cbf79576
# combined_spectra23-28.fits     LP_2442_gp5  563d3c59db1
# combined_spectra29-32.fits     LP_2442_gp2  2c620c86315
# combined_spectra33-37.fits    Telluric_STD  TelluricSTD
# combined_spectra45-47.fits     LP_2442_gp5  5a414c74fee
# combined_spectra48-50.fits     LP_2442_gp2  25661373b6e
# combined_spectra51-55.fits     LP_2442_gp2  2afb04570cb
# combined_spectra56-58.fits     LP_2442_gp2  20e00a62ae2
# combined_spectra66-70.fits     LP_2442_gp2  21d13cc4438
# combined_spectra71-74.fits     LP_2442_gp5  5aad62c409d
# combined_spectra75-77.fits     LP_2442_gp2  2b898f01c45
# combined_spectra85-87.fits          RV_STD        RVSTD
# combined_spectra93-96.fits     LP_2442_gp2  28de8227488
# combined_spectra104-106.fits   LP_2442_gp2  2aff1d5e562
# combined_spectra107-110.fits   LP_2442_gp2  246df9c59d2
# combined_spectra111-114.fits   LP_2442_gp2  24247745ed7
# combined_spectra115-118.fits  Telluric_STD  TelluricSTD
# combined_spectra119-123.fits   LP_2442_gp2  2e1ca0dae36
#
#                                        extracted_spec_fits  \
# combined_spectra1-6.fits          combined_spectra1-6.fits
# combined_spectra14-18.fits      combined_spectra14-18.fits
# combined_spectra19-22.fits      combined_spectra19-22.fits
# combined_spectra23-28.fits      combined_spectra23-28.fits
# combined_spectra29-32.fits      combined_spectra29-32.fits
# combined_spectra33-37.fits      combined_spectra33-37.fits
# combined_spectra45-47.fits      combined_spectra45-47.fits
# combined_spectra48-50.fits      combined_spectra48-50.fits
# combined_spectra51-55.fits      combined_spectra51-55.fits
# combined_spectra56-58.fits      combined_spectra56-58.fits
# combined_spectra66-70.fits      combined_spectra66-70.fits
# combined_spectra71-74.fits      combined_spectra71-74.fits
# combined_spectra75-77.fits      combined_spectra75-77.fits
# combined_spectra85-87.fits      combined_spectra85-87.fits
# combined_spectra93-96.fits      combined_spectra93-96.fits
# combined_spectra104-106.fits  combined_spectra104-106.fits
# combined_spectra107-110.fits  combined_spectra107-110.fits
# combined_spectra111-114.fits  combined_spectra111-114.fits
# combined_spectra115-118.fits  combined_spectra115-118.fits
# combined_spectra119-123.fits  combined_spectra119-123.fits
#
#                                        combined_img_fits        flat_fits  \
# combined_spectra1-6.fits                combined1-6.fits    flat7-11.fits
# combined_spectra14-18.fits            combined14-18.fits    flat7-11.fits
# combined_spectra19-22.fits    combined_spectra19-22.fits    flat7-11.fits
# combined_spectra23-28.fits    combined_spectra23-28.fits    flat7-11.fits
# combined_spectra29-32.fits    combined_spectra29-32.fits    flat7-11.fits
# combined_spectra33-37.fits    combined_spectra33-37.fits    flat7-11.fits
# combined_spectra45-47.fits    combined_spectra45-47.fits   flat38-42.fits
# combined_spectra48-50.fits    combined_spectra48-50.fits   flat38-42.fits
# combined_spectra51-55.fits    combined_spectra51-55.fits   flat38-42.fits
# combined_spectra56-58.fits            combined56-58.fits   flat38-42.fits
# combined_spectra66-70.fits            combined66-70.fits   flat59-63.fits
# combined_spectra71-74.fits            combined71-74.fits   flat59-63.fits
# combined_spectra75-77.fits            combined75-77.fits   flat59-63.fits
# combined_spectra85-87.fits            combined85-87.fits   flat78-82.fits
# combined_spectra93-96.fits            combined93-96.fits   flat78-82.fits
# combined_spectra104-106.fits        combined104-106.fits  flat97-101.fits
# combined_spectra107-110.fits        combined107-110.fits  flat97-101.fits
# combined_spectra111-114.fits        combined111-114.fits  flat97-101.fits
# combined_spectra115-118.fits        combined115-118.fits  flat97-101.fits
# combined_spectra119-123.fits        combined119-123.fits  flat97-101.fits
#
#                                      wvl_cal_fits  \
# combined_spectra1-6.fits        wavecal12-13.fits
# combined_spectra14-18.fits      wavecal12-13.fits
# combined_spectra19-22.fits      wavecal12-13.fits
# combined_spectra23-28.fits      wavecal12-13.fits
# combined_spectra29-32.fits      wavecal12-13.fits
# combined_spectra33-37.fits      wavecal12-13.fits
# combined_spectra45-47.fits      wavecal43-44.fits
# combined_spectra48-50.fits      wavecal43-44.fits
# combined_spectra51-55.fits      wavecal43-44.fits
# combined_spectra56-58.fits      wavecal43-44.fits
# combined_spectra66-70.fits      wavecal64-65.fits
# combined_spectra71-74.fits      wavecal64-65.fits
# combined_spectra75-77.fits      wavecal64-65.fits
# combined_spectra85-87.fits      wavecal83-84.fits
# combined_spectra93-96.fits      wavecal83-84.fits
# combined_spectra104-106.fits  wavecal102-103.fits
# combined_spectra107-110.fits  wavecal102-103.fits
# combined_spectra111-114.fits  wavecal102-103.fits
# combined_spectra115-118.fits  wavecal102-103.fits
# combined_spectra119-123.fits  wavecal102-103.fits
#
#                                                                    src_img_fits  \
# combined_spectra1-6.fits      ["icm.2023A023.230615.fname.00001.a.fits", "ic...
# combined_spectra14-18.fits    ["icm.2023A023.230615.fname.00014.a.fits", "ic...
# combined_spectra19-22.fits                                                  NaN
# combined_spectra23-28.fits                                                  NaN
# combined_spectra29-32.fits                                                  NaN
# combined_spectra33-37.fits                                                  NaN
# combined_spectra45-47.fits                                                  NaN
# combined_spectra48-50.fits                                                  NaN
# combined_spectra51-55.fits                                                  NaN
# combined_spectra56-58.fits    ["icm.2023A023.230615.fname.00056.a.fits", "ic...
# combined_spectra66-70.fits    ["icm.2023A023.230615.fname.00066.a.fits", "ic...
# combined_spectra71-74.fits    ["icm.2023A023.230615.fname.00071.a.fits", "ic...
# combined_spectra75-77.fits    ["icm.2023A023.230615.fname.00075.a.fits", "ic...
# combined_spectra85-87.fits    ["icm.2023A023.230615.fname.00085.a.fits", "ic...
# combined_spectra93-96.fits    ["icm.2023A023.230615.fname.00093.a.fits", "ic...
# combined_spectra104-106.fits  ["icm.2023A023.230615.fname.00104.a.fits", "ic...
# combined_spectra107-110.fits  ["icm.2023A023.230615.fname.00107.a.fits", "ic...
# combined_spectra111-114.fits  ["icm.2023A023.230615.fname.00111.a.fits", "ic...
# combined_spectra115-118.fits  ["icm.2023A023.230615.fname.00115.a.fits", "ic...
# combined_spectra119-123.fits  ["icm.2023A023.230615.fname.00119.a.fits", "ic...
#
#                               is_src_img_fits_log_consistent  \
# combined_spectra1-6.fits                                True
# combined_spectra14-18.fits                             False
# combined_spectra19-22.fits                             False
# combined_spectra23-28.fits                             False
# combined_spectra29-32.fits                             False
# combined_spectra33-37.fits                             False
# combined_spectra45-47.fits                             False
# combined_spectra48-50.fits                             False
# combined_spectra51-55.fits                             False
# combined_spectra56-58.fits                             False
# combined_spectra66-70.fits                             False
# combined_spectra71-74.fits                              True
# combined_spectra75-77.fits                             False
# combined_spectra85-87.fits                             False
# combined_spectra93-96.fits                              True
# combined_spectra104-106.fits                           False
# combined_spectra107-110.fits                            True
# combined_spectra111-114.fits                            True
# combined_spectra115-118.fits                            True
# combined_spectra119-123.fits                           False
#
#                                                               src_img_fits_spec  \
# combined_spectra1-6.fits      ["icm.2023A023.230615.fname.00001.a.fits", "ic...
# combined_spectra14-18.fits                                                   []
# combined_spectra19-22.fits    ["icm.2023A023.230615.fname.00019.a.fits", "ic...
# combined_spectra23-28.fits    ["icm.2023A023.230615.fname.00023.a.fits", "ic...
# combined_spectra29-32.fits    ["icm.2023A023.230615.fname.00029.a.fits", "ic...
# combined_spectra33-37.fits                                                   []
# combined_spectra45-47.fits                                                   []
# combined_spectra48-50.fits                                                   []
# combined_spectra51-55.fits                                                   []
# combined_spectra56-58.fits                                                   []
# combined_spectra66-70.fits                                                   []
# combined_spectra71-74.fits    ["icm.2023A023.230615.fname.00071.a.fits", "ic...
# combined_spectra75-77.fits                                                   []
# combined_spectra85-87.fits                                                   []
# combined_spectra93-96.fits    ["icm.2023A023.230615.fname.00093.a.fits", "ic...
# combined_spectra104-106.fits                                                 []
# combined_spectra107-110.fits  ["icm.2023A023.230615.fname.00107.a.fits", "ic...
# combined_spectra111-114.fits  ["icm.2023A023.230615.fname.00111.a.fits", "ic...
# combined_spectra115-118.fits  ["icm.2023A023.230615.fname.00115.a.fits", "ic...
# combined_spectra119-123.fits                                                 []
#
#                                                       src_img_fits_combined_img  \
# combined_spectra1-6.fits      ["icm.2023A023.230615.fname.00001.a.fits", "ic...
# combined_spectra14-18.fits    ["icm.2023A023.230615.fname.00014.a.fits", "ic...
# combined_spectra19-22.fits                                                  NaN
# combined_spectra23-28.fits                                                  NaN
# combined_spectra29-32.fits                                                  NaN
# combined_spectra33-37.fits                                                  NaN
# combined_spectra45-47.fits                                                  NaN
# combined_spectra48-50.fits                                                  NaN
# combined_spectra51-55.fits                                                  NaN
# combined_spectra56-58.fits    ["icm.2023A023.230615.fname.00056.a.fits", "ic...
# combined_spectra66-70.fits    ["icm.2023A023.230615.fname.00066.a.fits", "ic...
# combined_spectra71-74.fits    ["icm.2023A023.230615.fname.00071.a.fits", "ic...
# combined_spectra75-77.fits    ["icm.2023A023.230615.fname.00075.a.fits", "ic...
# combined_spectra85-87.fits    ["icm.2023A023.230615.fname.00085.a.fits", "ic...
# combined_spectra93-96.fits    ["icm.2023A023.230615.fname.00093.a.fits", "ic...
# combined_spectra104-106.fits  ["icm.2023A023.230615.fname.00104.a.fits", "ic...
# combined_spectra107-110.fits  ["icm.2023A023.230615.fname.00107.a.fits", "ic...
# combined_spectra111-114.fits  ["icm.2023A023.230615.fname.00111.a.fits", "ic...
# combined_spectra115-118.fits  ["icm.2023A023.230615.fname.00115.a.fits", "ic...
# combined_spectra119-123.fits  ["icm.2023A023.230615.fname.00119.a.fits", "ic...
#
#                               ... snr_mean_order334 snr_std_order334  \
# combined_spectra1-6.fits      ...        132.971255        41.735509
# combined_spectra14-18.fits    ...         46.231234        18.897741
# combined_spectra19-22.fits    ...         44.877625        17.811921
# combined_spectra23-28.fits    ...         41.840172        17.968538
# combined_spectra29-32.fits    ...         42.036547        16.900362
# combined_spectra33-37.fits    ...        140.342591        44.906867
# combined_spectra45-47.fits    ...         62.676899        22.079735
# combined_spectra48-50.fits    ...         32.070329        13.302494
# combined_spectra51-55.fits    ...         31.455264        13.929453
# combined_spectra56-58.fits    ...          26.06798        11.404086
# combined_spectra66-70.fits    ...         24.018736        12.149895
# combined_spectra71-74.fits    ...         50.105494        19.235137
# combined_spectra75-77.fits    ...          29.08743        12.253719
# combined_spectra85-87.fits    ...          82.90686         27.91496
# combined_spectra93-96.fits    ...         28.610041        13.145729
# combined_spectra104-106.fits  ...         30.926764        13.382482
# combined_spectra107-110.fits  ...         34.931801        14.947338
# combined_spectra111-114.fits  ...         31.168269        13.915187
# combined_spectra115-118.fits  ...         148.18676        47.098587
# combined_spectra119-123.fits  ...         42.131916        17.768098
#
#                              snr_mean_order335 snr_std_order335  \
# combined_spectra1-6.fits            133.661567        40.760635
# combined_spectra14-18.fits           45.179039        18.053243
# combined_spectra19-22.fits           43.890599        17.153313
# combined_spectra23-28.fits           40.600881        17.127629
# combined_spectra29-32.fits           41.024821        16.389115
# combined_spectra33-37.fits          141.724523        44.388851
# combined_spectra45-47.fits           62.398522          21.4107
# combined_spectra48-50.fits           31.056489        12.671622
# combined_spectra51-55.fits           30.896105        13.308516
# combined_spectra56-58.fits           25.556062        10.942409
# combined_spectra66-70.fits           23.612189        11.456644
# combined_spectra71-74.fits           49.668052         18.36195
# combined_spectra75-77.fits           28.562335        11.735426
# combined_spectra85-87.fits           82.985307        26.906771
# combined_spectra93-96.fits           27.912801        12.392309
# combined_spectra104-106.fits         30.251338        12.637977
# combined_spectra107-110.fits         34.126838        14.149446
# combined_spectra111-114.fits         30.232908        13.361644
# combined_spectra115-118.fits        149.853847        46.399846
# combined_spectra119-123.fits         41.518628        17.037747
#
#                              snr_mean_order336 snr_std_order336  \
# combined_spectra1-6.fits            132.268753        40.070592
# combined_spectra14-18.fits           44.030478        17.962211
# combined_spectra19-22.fits           42.750427         17.10801
# combined_spectra23-28.fits           39.350394         17.04386
# combined_spectra29-32.fits           39.942302        16.160766
# combined_spectra33-37.fits          140.257232        43.864893
# combined_spectra45-47.fits           61.628397        21.767497
# combined_spectra48-50.fits           29.971639        12.585006
# combined_spectra51-55.fits           30.073961        13.387663
# combined_spectra56-58.fits           24.987232        10.912346
# combined_spectra66-70.fits           22.917615        11.090573
# combined_spectra71-74.fits           48.659784         18.21719
# combined_spectra75-77.fits           27.962427         11.34671
# combined_spectra85-87.fits           82.567834         27.26417
# combined_spectra93-96.fits           26.784358        11.946244
# combined_spectra104-106.fits         29.239004        12.255997
# combined_spectra107-110.fits         33.089352        14.043686
# combined_spectra111-114.fits         29.028372        12.729345
# combined_spectra115-118.fits        148.385559         45.89902
# combined_spectra119-123.fits         40.282954        16.707196
#
#                              snr_mean_order337 snr_std_order337  \
# combined_spectra1-6.fits            127.108475        39.284463
# combined_spectra14-18.fits           39.826317        16.738143
# combined_spectra19-22.fits           39.151147        16.018455
# combined_spectra23-28.fits           34.683506        15.395708
# combined_spectra29-32.fits           36.183616        15.141964
# combined_spectra33-37.fits          137.644856        43.870178
# combined_spectra45-47.fits           58.834135        20.805522
# combined_spectra48-50.fits            27.19876        11.598383
# combined_spectra51-55.fits           27.111755        11.976359
# combined_spectra56-58.fits           22.814232        10.039584
# combined_spectra66-70.fits           20.975984         9.984219
# combined_spectra71-74.fits           46.026234        17.321931
# combined_spectra75-77.fits            26.39058        10.665836
# combined_spectra85-87.fits           80.842652        26.886463
# combined_spectra93-96.fits           23.591369         10.87594
# combined_spectra104-106.fits         26.470239        11.508358
# combined_spectra107-110.fits         29.804211        12.684042
# combined_spectra111-114.fits          25.57045        11.682334
# combined_spectra115-118.fits         146.15901        46.062671
# combined_spectra119-123.fits         36.389682         15.25726
#
#                              snr_mean_order338 snr_std_order338
# combined_spectra1-6.fits            118.297095        42.264053
# combined_spectra14-18.fits           31.113917         17.26133
# combined_spectra19-22.fits           31.316189        16.371122
# combined_spectra23-28.fits           26.175485        16.709298
# combined_spectra29-32.fits           28.251501         15.70385
# combined_spectra33-37.fits          129.984569        46.039342
# combined_spectra45-47.fits           51.679282        21.943074
# combined_spectra48-50.fits           21.219591        12.345532
# combined_spectra51-55.fits           21.148789        13.258377
# combined_spectra56-58.fits           18.229189        10.467942
# combined_spectra66-70.fits            18.41343         11.09494
# combined_spectra71-74.fits           40.394463        17.600815
# combined_spectra75-77.fits           23.461594        11.448707
# combined_spectra85-87.fits           75.475897        27.927779
# combined_spectra93-96.fits           16.130694        12.476938
# combined_spectra104-106.fits         20.115205        11.776717
# combined_spectra107-110.fits         22.501575        13.547123
# combined_spectra111-114.fits         17.507675        11.864272
# combined_spectra115-118.fits        136.253541        48.558877
# combined_spectra119-123.fits         27.203439        15.938926
#
# [20 rows x 184 columns]

# %%
# save the collected information as CSV file
merged_summary_df.to_csv(f'results/{obs_date}-summary.csv', index=False)
